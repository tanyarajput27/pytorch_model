# %% [markdown]
# <a href="https://colab.research.google.com/github/PalakDograCSE-AI2004/CVDL_Summer_Internship/blob/main/Building_ANN_model_using_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from torch import nn

# %%
data, target = make_circles(n_samples=1000, noise=0.03, random_state=10)

# %%
data[:5]
# Out:
# array([[-0.31031434, -0.68316883],
#        [ 0.65484283, -0.40810234],
#        [ 0.72067081,  0.42182061],
#        [-0.54407753,  0.81163728],
#        [-0.81208571, -0.14351782]])

# %%
target[:5]
# Out:
# array([1, 1, 1, 0, 1])

# %%
plt.scatter(data[:,0], data[:,1], c=target)
plt.show()

# %%
# convert numpy array into tensor object
X = torch.from_numpy(data).type(torch.float)
y = torch.from_numpy(target).type(torch.float)

# %%
# test size is 0.25 that means 25% data is reserved for testing purpose
# we apply deep learning on training data and then test our model on testing data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X.shape
# Out:
# torch.Size([1000, 2])

# %%
x_train.shape
# Out:
# torch.Size([750, 2])

# %%
# Building Model

# %%
# setup GPU for deep learning model
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cpu'

# %%
# nn.Module is a parent class of our Model class
class Model(nn.Module):
  # constructor of our class
  def __init__(self):
    # calling parent class constructor
    super().__init__()
    # create input layer
    # in_features - input neurons in our input layer
    # out_features - hidden layer neurons that is connected with input layer
    # nn.Linear - it applies linear equation : x.w + bias
    self.layer_1 = nn.Linear(in_features=2, out_features=4)
    self.layer_2 = nn.Linear(in_features=4, out_features=1)

  def forward(self, input_data):
    # first we pass our input data to forward method
    # then layer_1 will receive input data
    # then we pass layer_1 output to layer_2
    # then we return output that is coming out from layer_2
    x = self.layer_1(input_data)
    return self.layer_2(x)

# %%
model = Model().to(device)

# %%
model
# Out:
# Model(
#   (layer_1): Linear(in_features=2, out_features=4, bias=True)
#   (layer_2): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
model_2 = nn.Sequential(
    nn.Linear(in_features=2, out_features=4),
    nn.Linear(in_features=4, out_features=1)
).to(device)

# %%
model_2
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=4, bias=True)
#   (1): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
# Backpropagation
  # Loss Function
    # Binary Cross Entropy
    # Cross Entropy
    # MAE - Mean Absolute Error

  # Optimization
    # Stochastic Gradient Descent
    # Adam Optimizer

# %%
# we are using Binary Cross Entropy Loss Function
loss = nn.BCEWithLogitsLoss()

# optimization technique - Stochastic Gradient Descent
# params - trainable parameters - weights and bias
# lr - learning rate
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.1)

# Evaluation metric
def accuracy(y_true, y_pred):
  # y_true = 1, y_pred = 1
  # y_true = 0, y_pred = 0
  correct_classification = torch.eq(y_true, y_pred).sum().item()
  acc = (correct_classification / len(y_pred)) * 100
  return acc

# %%
# here we are calling forward method of our model
y_logits = model(x_test)[:5]

# %%
y_logits
# Out:
# tensor([[0.6728],
#         [0.4587],
#         [0.5000],
#         [0.6632],
#         [0.6411]], grad_fn=<SliceBackward0>)

# %%
y_pred_probs = torch.sigmoid(y_logits)

# %%
y_pred_probs
# Out:
# tensor([[0.6621],
#         [0.6127],
#         [0.6225],
#         [0.6600],
#         [0.6550]], grad_fn=<SigmoidBackward0>)

# %%
y_pred = torch.round(y_pred_probs)

# %%
y_pred
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]], grad_fn=<RoundBackward0>)

# %%
y_test[:5]
# Out:
# tensor([0., 0., 1., 1., 1.])

# %%
y_pred = y_pred.squeeze()

# %%
y_pred
# Out:
# tensor([1., 1., 1., 1., 1.], grad_fn=<SqueezeBackward0>)

# %%
accuracy(y_test[:5], y_pred)
# Out:
# 60.0

# %%
epochs = 100

x_train, y_train = x_train.to(device), y_train.to(device)
x_test, y_test = x_test.to(device), y_test.to(device)

for epoch in range(epochs):
  # training model
  model.train()

  # apply feedforward
  y_logits = model(x_train).squeeze()
  # get predictions on training data
  y_pred = torch.round(torch.sigmoid(y_logits))

  # now find out loss
  # apply binary cross entropy to get loss
  train_loss = loss(y_logits, y_train)
  acc = accuracy(y_train, y_pred)

  # apply optimization - apply gradient descent
  optimizer.zero_grad()
  # backpropagation
  train_loss.backward()
  optimizer.step()

  # model evaluation
  model.eval()
  with torch.inference_mode():
    y_pred_test = model(x_test).squeeze()
    test_pred = torch.round(torch.sigmoid(y_pred_test))
    test_loss = loss(y_pred_test, y_test)
    test_acc = accuracy(y_test, test_pred)

  print(f"Epoch : {epoch} | Loss : {train_loss:.4f} | Acc : {acc:.2f} | Test Loss : {test_loss:.4f} | Test Acc : {test_acc:.2f}")
# Out:
# Epoch : 0 | Loss : 0.7466 | Acc : 49.20 | Test Loss : 0.7214 | Test Acc : 52.40
# Epoch : 1 | Loss : 0.7413 | Acc : 49.20 | Test Loss : 0.7176 | Test Acc : 52.40
# Epoch : 2 | Loss : 0.7366 | Acc : 49.20 | Test Loss : 0.7142 | Test Acc : 52.40
# Epoch : 3 | Loss : 0.7324 | Acc : 49.20 | Test Loss : 0.7112 | Test Acc : 52.40
# Epoch : 4 | Loss : 0.7285 | Acc : 49.20 | Test Loss : 0.7086 | Test Acc : 52.40
# Epoch : 5 | Loss : 0.7251 | Acc : 49.20 | Test Loss : 0.7062 | Test Acc : 52.40
# Epoch : 6 | Loss : 0.7220 | Acc : 49.20 | Test Loss : 0.7042 | Test Acc : 52.40
# Epoch : 7 | Loss : 0.7193 | Acc : 49.20 | Test Loss : 0.7023 | Test Acc : 52.40
# Epoch : 8 | Loss : 0.7168 | Acc : 49.20 | Test Loss : 0.7007 | Test Acc : 52.40
# Epoch : 9 | Loss : 0.7146 | Acc : 49.20 | Test Loss : 0.6993 | Test Acc : 52.40
# Epoch : 10 | Loss : 0.7126 | Acc : 49.20 | Test Loss : 0.6980 | Test Acc : 52.40
# Epoch : 11 | Loss : 0.7108 | Acc : 49.20 | Test Loss : 0.6970 | Test Acc : 52.40
# Epoch : 12 | Loss : 0.7091 | Acc : 49.20 | Test Loss : 0.6960 | Test Acc : 52.40
# Epoch : 13 | Loss : 0.7077 | Acc : 49.20 | Test Loss : 0.6952 | Test Acc : 52.40
# Epoch : 14 | Loss : 0.7064 | Acc : 49.20 | Test Loss : 0.6944 | Test Acc : 52.40
# Epoch : 15 | Loss : 0.7052 | Acc : 49.20 | Test Loss : 0.6938 | Test Acc : 52.40
# Epoch : 16 | Loss : 0.7042 | Acc : 49.20 | Test Loss : 0.6933 | Test Acc : 52.40
# Epoch : 17 | Loss : 0.7032 | Acc : 49.20 | Test Loss : 0.6928 | Test Acc : 52.40
# Epoch : 18 | Loss : 0.7024 | Acc : 49.20 | Test Loss : 0.6924 | Test Acc : 52.40
# Epoch : 19 | Loss : 0.7016 | Acc : 49.20 | Test Loss : 0.6921 | Test Acc : 52.40
# Epoch : 20 | Loss : 0.7010 | Acc : 49.20 | Test Loss : 0.6918 | Test Acc : 52.40
# Epoch : 21 | Loss : 0.7003 | Acc : 49.20 | Test Loss : 0.6915 | Test Acc : 52.40
# Epoch : 22 | Loss : 0.6998 | Acc : 49.20 | Test Loss : 0.6913 | Test Acc : 52.40
# Epoch : 23 | Loss : 0.6993 | Acc : 49.20 | Test Loss : 0.6911 | Test Acc : 52.40
# Epoch : 24 | Loss : 0.6989 | Acc : 49.20 | Test Loss : 0.6910 | Test Acc : 52.40
# Epoch : 25 | Loss : 0.6985 | Acc : 49.20 | Test Loss : 0.6909 | Test Acc : 52.40
# Epoch : 26 | Loss : 0.6981 | Acc : 49.20 | Test Loss : 0.6908 | Test Acc : 52.40
# Epoch : 27 | Loss : 0.6978 | Acc : 49.20 | Test Loss : 0.6907 | Test Acc : 52.40
# Epoch : 28 | Loss : 0.6975 | Acc : 49.33 | Test Loss : 0.6907 | Test Acc : 54.40
# Epoch : 29 | Loss : 0.6972 | Acc : 51.07 | Test Loss : 0.6906 | Test Acc : 56.00
# Epoch : 30 | Loss : 0.6970 | Acc : 55.20 | Test Loss : 0.6906 | Test Acc : 58.00
# Epoch : 31 | Loss : 0.6968 | Acc : 57.47 | Test Loss : 0.6906 | Test Acc : 61.20
# Epoch : 32 | Loss : 0.6966 | Acc : 58.53 | Test Loss : 0.6906 | Test Acc : 58.40
# Epoch : 33 | Loss : 0.6964 | Acc : 56.67 | Test Loss : 0.6906 | Test Acc : 54.80
# Epoch : 34 | Loss : 0.6963 | Acc : 54.40 | Test Loss : 0.6906 | Test Acc : 55.20
# Epoch : 35 | Loss : 0.6961 | Acc : 53.33 | Test Loss : 0.6906 | Test Acc : 54.00
# Epoch : 36 | Loss : 0.6960 | Acc : 53.33 | Test Loss : 0.6907 | Test Acc : 53.20
# Epoch : 37 | Loss : 0.6959 | Acc : 52.93 | Test Loss : 0.6907 | Test Acc : 52.80
# Epoch : 38 | Loss : 0.6958 | Acc : 52.93 | Test Loss : 0.6907 | Test Acc : 53.20
# Epoch : 39 | Loss : 0.6957 | Acc : 52.00 | Test Loss : 0.6908 | Test Acc : 53.20
# Epoch : 40 | Loss : 0.6956 | Acc : 51.33 | Test Loss : 0.6908 | Test Acc : 54.40
# Epoch : 41 | Loss : 0.6955 | Acc : 51.07 | Test Loss : 0.6908 | Test Acc : 54.00
# Epoch : 42 | Loss : 0.6954 | Acc : 51.07 | Test Loss : 0.6909 | Test Acc : 54.00
# Epoch : 43 | Loss : 0.6953 | Acc : 50.80 | Test Loss : 0.6909 | Test Acc : 53.60
# Epoch : 44 | Loss : 0.6953 | Acc : 50.40 | Test Loss : 0.6910 | Test Acc : 53.20
# Epoch : 45 | Loss : 0.6952 | Acc : 50.67 | Test Loss : 0.6910 | Test Acc : 54.00
# Epoch : 46 | Loss : 0.6952 | Acc : 50.53 | Test Loss : 0.6910 | Test Acc : 53.60
# Epoch : 47 | Loss : 0.6951 | Acc : 50.27 | Test Loss : 0.6911 | Test Acc : 54.00
# Epoch : 48 | Loss : 0.6951 | Acc : 50.27 | Test Loss : 0.6911 | Test Acc : 54.00
# Epoch : 49 | Loss : 0.6950 | Acc : 49.87 | Test Loss : 0.6912 | Test Acc : 54.40
# Epoch : 50 | Loss : 0.6950 | Acc : 50.27 | Test Loss : 0.6912 | Test Acc : 54.40
# Epoch : 51 | Loss : 0.6950 | Acc : 50.27 | Test Loss : 0.6912 | Test Acc : 54.00
# Epoch : 52 | Loss : 0.6949 | Acc : 50.13 | Test Loss : 0.6913 | Test Acc : 54.00
# Epoch : 53 | Loss : 0.6949 | Acc : 49.87 | Test Loss : 0.6913 | Test Acc : 54.00
# Epoch : 54 | Loss : 0.6949 | Acc : 49.60 | Test Loss : 0.6914 | Test Acc : 54.00
# Epoch : 55 | Loss : 0.6948 | Acc : 49.60 | Test Loss : 0.6914 | Test Acc : 54.00
# Epoch : 56 | Loss : 0.6948 | Acc : 49.33 | Test Loss : 0.6914 | Test Acc : 53.20
# Epoch : 57 | Loss : 0.6948 | Acc : 49.20 | Test Loss : 0.6915 | Test Acc : 52.80
# Epoch : 58 | Loss : 0.6948 | Acc : 49.20 | Test Loss : 0.6915 | Test Acc : 52.80
# Epoch : 59 | Loss : 0.6947 | Acc : 49.60 | Test Loss : 0.6915 | Test Acc : 52.80
# Epoch : 60 | Loss : 0.6947 | Acc : 49.47 | Test Loss : 0.6915 | Test Acc : 52.40
# Epoch : 61 | Loss : 0.6947 | Acc : 49.47 | Test Loss : 0.6916 | Test Acc : 52.40
# Epoch : 62 | Loss : 0.6947 | Acc : 49.47 | Test Loss : 0.6916 | Test Acc : 52.40
# Epoch : 63 | Loss : 0.6946 | Acc : 49.87 | Test Loss : 0.6916 | Test Acc : 52.40
# Epoch : 64 | Loss : 0.6946 | Acc : 50.00 | Test Loss : 0.6917 | Test Acc : 52.40
# Epoch : 65 | Loss : 0.6946 | Acc : 50.00 | Test Loss : 0.6917 | Test Acc : 52.00
# Epoch : 66 | Loss : 0.6946 | Acc : 50.00 | Test Loss : 0.6917 | Test Acc : 51.20
# Epoch : 67 | Loss : 0.6946 | Acc : 50.13 | Test Loss : 0.6917 | Test Acc : 51.20
# Epoch : 68 | Loss : 0.6946 | Acc : 50.13 | Test Loss : 0.6918 | Test Acc : 51.60
# Epoch : 69 | Loss : 0.6945 | Acc : 49.87 | Test Loss : 0.6918 | Test Acc : 51.60
# Epoch : 70 | Loss : 0.6945 | Acc : 49.60 | Test Loss : 0.6918 | Test Acc : 51.60
# Epoch : 71 | Loss : 0.6945 | Acc : 49.33 | Test Loss : 0.6918 | Test Acc : 51.20
# Epoch : 72 | Loss : 0.6945 | Acc : 49.47 | Test Loss : 0.6918 | Test Acc : 51.20
# Epoch : 73 | Loss : 0.6945 | Acc : 49.33 | Test Loss : 0.6919 | Test Acc : 52.00
# Epoch : 74 | Loss : 0.6945 | Acc : 49.20 | Test Loss : 0.6919 | Test Acc : 52.00
# Epoch : 75 | Loss : 0.6944 | Acc : 48.93 | Test Loss : 0.6919 | Test Acc : 52.00
# Epoch : 76 | Loss : 0.6944 | Acc : 48.80 | Test Loss : 0.6919 | Test Acc : 52.40
# Epoch : 77 | Loss : 0.6944 | Acc : 49.07 | Test Loss : 0.6919 | Test Acc : 52.40
# Epoch : 78 | Loss : 0.6944 | Acc : 49.07 | Test Loss : 0.6920 | Test Acc : 52.40
# Epoch : 79 | Loss : 0.6944 | Acc : 48.93 | Test Loss : 0.6920 | Test Acc : 52.00
# Epoch : 80 | Loss : 0.6944 | Acc : 49.07 | Test Loss : 0.6920 | Test Acc : 52.00
# Epoch : 81 | Loss : 0.6944 | Acc : 49.07 | Test Loss : 0.6920 | Test Acc : 52.00
# Epoch : 82 | Loss : 0.6944 | Acc : 48.93 | Test Loss : 0.6920 | Test Acc : 52.00
# Epoch : 83 | Loss : 0.6943 | Acc : 48.93 | Test Loss : 0.6920 | Test Acc : 52.00
# Epoch : 84 | Loss : 0.6943 | Acc : 48.80 | Test Loss : 0.6920 | Test Acc : 52.00
# Epoch : 85 | Loss : 0.6943 | Acc : 48.80 | Test Loss : 0.6921 | Test Acc : 52.00
# Epoch : 86 | Loss : 0.6943 | Acc : 48.93 | Test Loss : 0.6921 | Test Acc : 52.00
# Epoch : 87 | Loss : 0.6943 | Acc : 48.67 | Test Loss : 0.6921 | Test Acc : 52.00
# Epoch : 88 | Loss : 0.6943 | Acc : 48.67 | Test Loss : 0.6921 | Test Acc : 51.60
# Epoch : 89 | Loss : 0.6943 | Acc : 48.80 | Test Loss : 0.6921 | Test Acc : 52.00
# Epoch : 90 | Loss : 0.6943 | Acc : 48.80 | Test Loss : 0.6921 | Test Acc : 52.40
# Epoch : 91 | Loss : 0.6942 | Acc : 48.80 | Test Loss : 0.6921 | Test Acc : 52.40
# Epoch : 92 | Loss : 0.6942 | Acc : 49.20 | Test Loss : 0.6921 | Test Acc : 52.00
# Epoch : 93 | Loss : 0.6942 | Acc : 49.20 | Test Loss : 0.6922 | Test Acc : 51.20
# Epoch : 94 | Loss : 0.6942 | Acc : 49.20 | Test Loss : 0.6922 | Test Acc : 51.20
# Epoch : 95 | Loss : 0.6942 | Acc : 49.33 | Test Loss : 0.6922 | Test Acc : 51.20
# Epoch : 96 | Loss : 0.6942 | Acc : 49.33 | Test Loss : 0.6922 | Test Acc : 51.20
# Epoch : 97 | Loss : 0.6942 | Acc : 49.33 | Test Loss : 0.6922 | Test Acc : 51.20
# Epoch : 98 | Loss : 0.6942 | Acc : 49.33 | Test Loss : 0.6922 | Test Acc : 51.20
# Epoch : 99 | Loss : 0.6942 | Acc : 49.20 | Test Loss : 0.6922 | Test Acc : 51.20

# %%
y_train[:5]
# Out:
# tensor([1., 1., 1., 1., 0.])

# %%
y_pred[:5]
# Out:
# tensor([1., 1., 1., 0., 0.], grad_fn=<SliceBackward0>)

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Actual Train")
plt.scatter(x_train[:,0], x_train[:,1], c=y_train)
plt.subplot(1,2,2)
plt.title("Pred Train")
plt.scatter(x_train[:,0], x_train[:,1], c=y_pred.detach().numpy())
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Actual Test")
plt.scatter(x_test[:,0], x_test[:,1], c=y_test)
plt.subplot(1,2,2)
plt.title("Pred Test")
plt.scatter(x_test[:,0], x_test[:,1], c=test_pred.detach().numpy())
plt.show()
